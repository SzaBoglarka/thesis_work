# %%
from __future__ import print_function

# %matplotlib inline

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# 8.2.3

# %%
# This cell should have a 'parameters' tag for papermill parameterized notebook execution
results_folder = 'path_to_base_directory'     # MOUSE or RAT
target_data = 'path_to_target_data'           # MOUSE or RAT
stim_data = 'path_to_stim_file'               # MOUSE or RAT

# %%
# Parameters
results_folder = "/home/szabobogi/hippounit_standard_features/validation_results_RAT/"
target_data = "/home/szabobogi/BluePyEfe_standard_features/BluePyEfe/FINAL_PV_PTI_data/features_for_validation/standard_features_for_validation_RAT_FINAL.json"
stim_data = "/home/szabobogi/BluePyEfe_standard_features/BluePyEfe/FINAL_PV_PTI_data/stim_for_validation/stim_for_validation_RAT_FINAL.json"

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "/home/szabobogi/BC_modells/TzilivakiEtal_FSBCs_model/Multicompartmental_Biophysical_models/mechanism/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = results_folder

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Tzilivaki4_2019"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/szabobogi/BC_modells/TzilivakiEtal_FSBCs_model/Multicompartmental_Biophysical_models/experiment/main_model_Somogyi_4.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None
#Template is not loaded directly by HippoUnit, because "current_balanceFS(-68)" has to be called after initializing the template 

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'FScell[0].soma[0]'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -65
#model.dt = 0.1

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - with global features
#
# It evaluates the model against experimental eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection using standardized current amplitudes.

# %%
# Load target data 
with open(target_data) as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
with open(stim_data, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTestWithGlobalFeatures(
    observation=observation, 
    config=config, 
    force_run=True, 
    show_plot=False, 
    save_all = True, 
    base_directory=base_directory,
    AP_detection_thd = -10,
    steady_state_threshold=30,
    highfreq_firing_threshold=150)


# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# efel version: 5.5.5
# AP detection threshold is set to -10
# - running amplitude: 0.2 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.25 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.15 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.04 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: -0.1 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.1 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.06 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.08 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: -0.02 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.02 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.3 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.35 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.4 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.5 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.6 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.7 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.8 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# - running amplitude: 0.9 on model: Tzilivaki4_2019 at: FScell[0].soma[0](0.5)
# The model did not exceed the frequency threshold of 150
# Using the current 0.9 with the maximum firing frequency: 143.0
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_width, An error occurred while computing the feature, feature is not found. Feature AP_begin_width not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP2_begin_width, An error occurred while computing the feature, feature is not found. Feature AP_begin_width not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_width,
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_begin_width,
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width, An error occurred while computing the feature, feature is not found. Feature AP_rise_indices not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width, An error occurred while computing the feature, feature is not found. Feature AP_rise_indices not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width_change, An error occurred while computing the feature, feature is not found. Feature AP_rise_indices not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating AP_duration_half_width_change, An error occurred while computing the feature, feature is not found. Feature AP_rise_indices not found
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/pyfeatures/pyfeatures.py:452: RuntimeWarning: Error while calculating time_constant, An error occurred while computing the feature, feature is not found. Trace fall time too short.
#   warnings.warn(
# The figures are saved in the directory:  /home/szabobogi/hippounit_standard_features/validation_results_RAT/figs/somaticfeat/Tzilivaki4_2019/
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1103: RuntimeWarning: All-NaN axis encountered
#   minx = np.nanmin(masked_verts[..., 0])
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1104: RuntimeWarning: All-NaN axis encountered
#   maxx = np.nanmax(masked_verts[..., 0])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Features excluded (due to invalid values): AP2_begin_width.highfreq_firing_current, AP2_begin_width.steady_state_current, AP_begin_width.highfreq_firing_current, AP_begin_width.steady_state_current, AP_duration_half_width.highfreq_firing_current, AP_duration_half_width.steady_state_current, AP_duration_half_width_change.highfreq_firing_current, AP_duration_half_width_change.steady_state_current, time_constant.standard_negative_current
# Number of features succesfully evaluated: 185/194
# Results are saved in the directory:  /home/szabobogi/hippounit_standard_features/validation_results_RAT/results/somaticfeat/Tzilivaki4_2019/
# /home/szabobogi/hippounit_standard_features/hippounit/plottools.py:119: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figname, facecolor='white')
# /home/szabobogi/hippounit_standard_features/hippounit/tests/test_SomaticFeaturesTest.py:1032: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize = (210/25.4, 297/25.4))
