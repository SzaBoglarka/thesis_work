# %%
from __future__ import print_function

# %matplotlib inline

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# 7.8.2

# %%
# This cell should have a 'parameters' tag for papermill parameterized notebook execution
results_folder = 'path_to_base_directory'     # MOUSE or RAT
target_data = 'path_to_target_data'           # MOUSE or RAT
stim_data = 'path_to_stim_file'               # MOUSE or RAT

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "/home/szabobogi/BC_modells/Hu_modellek/WB_modell_es_reszletes_modell_(2018)_(aktiv)/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = results_folder

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Hu(rb)_2018"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/szabobogi/BC_modells/Hu_modellek/WB_modell_es_reszletes_modell_(2018)_(aktiv)/test1_rb.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = "soma"
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = None

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -65
#model.dt = 0.1

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - with global features
#
# It evaluates the model against experimental eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection using standardized current amplitudes.

# %%
# Load target data 
with open(target_data) as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
with open(stim_data, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTestWithGlobalFeatures(
    observation=observation, 
    config=config, 
    force_run=True, 
    show_plot=False, 
    save_all = True, 
    base_directory=base_directory,
    AP_detection_thd = -10,
    steady_state_threshold=30,
    highfreq_firing_threshold=150)


# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -0.1 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.09 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.07 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.06 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.08 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.05 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)- running amplitude: -0.04 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)- running amplitude: -0.03 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
#
# - running amplitude: -0.01 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: -0.02 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
#
# - running amplitude: 0.01 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.02 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.03 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.04 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)- running amplitude: 0.05 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
#
# - running amplitude: 0.06 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.07 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.08 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.09 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.1 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.15 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.2 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.25 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.3 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.4 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.5 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# - running amplitude: 0.6 on model: Hu_(WB)_2018_rb_standard at: soma(0.5)
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature AHP_depth_diff:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature ISI_CV:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature ISI_log_slope:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature ISI_log_slope_skip:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature ISI_semilog_slope:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature ISI_values:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature adaptation_index:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
# Parameter [offset] is missing in double map. In the python interface this can be set using the setDoubleSetting() function
#
# Minimum 4 spike needed for feature [adaptation_index].
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature adaptation_index2:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  At least 4 spikes needed for adaptation_index2.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature amp_drop_first_last:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
# At least 2 spikes needed for calculation of amp_drop_first_last.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature amp_drop_first_second:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
# At least 2 spikes needed for calculation of amp_drop_first_second.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature amp_drop_second_last:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
# At least 3 spikes needed for calculation of amp_drop_second_last.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature burst_mean_freq:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Error: More than 5 spike is needed for burst calculation.
#
# Feature [burst_ISI_indices] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature burst_number:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# ...
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature max_amp_difference:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
# At least 2 spikes needed for calculation of max_amp_difference.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature single_burst_ratio:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature spike_width2:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Error: More than one spike is needed for spikewidth calculation.
#
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/efel/api.py:499: RuntimeWarning: Error while calculating feature time_to_second_spike:
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
# Voltage never goes below or above threshold in spike detection.
#
#  Two spikes required for time_to_second_spike.
#
#   warnings.warn(
# The figures are saved in the directory:  ./validation_results/figs/somaticfeat/Hu_(WB)_2018_rb_standard/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# No handles with labels found to put in legend.
# /home/szabobogi/hippounit_standard_features/hippounit/hippounit/scores/score_ZScore_somaticSpiking.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   feature_error = abs(p_value - o_mean)/o_std
# Features excluded (due to invalid values): AHP2_depth_from_peak.rheobase_current, AHP_depth_diff.rheobase_current, AP2_AP1_peak_diff.rheobase_current, AP2_amp.rheobase_current, AP2_begin_voltage.rheobase_current, AP2_begin_width.rheobase_current, AP2_peak.rheobase_current, AP2_width.rheobase_current, AP_amplitude.rheobase_current, AP_amplitude_change.rheobase_current, AP_begin_voltage.rheobase_current, AP_begin_width.rheobase_current, AP_duration.rheobase_current, AP_duration_change.rheobase_current, AP_duration_half_width.rheobase_current, AP_duration_half_width_change.rheobase_current, AP_rise_rate.rheobase_current, AP_rise_rate_change.rheobase_current, AP_rise_time.rheobase_current, AP_width.rheobase_current, ISI_CV.rheobase_current, ISI_log_slope.rheobase_current, ISI_log_slope_skip.rheobase_current, ISI_semilog_slope.rheobase_current, ISI_values.rheobase_current, Spikecount.rheobase_prev_current, Spikecount_stimint.rheobase_prev_current, adaptation_index.rheobase_current, adaptation_index2.rheobase_current, amp_drop_first_last.rheobase_current, amp_drop_first_second.rheobase_current, amp_drop_second_last.rheobase_current, burst_mean_freq.rheobase_current, burst_number.rheobase_current, doublet_ISI.rheobase_current, fast_AHP.rheobase_current, fast_AHP_change.rheobase_current, initburst_sahp.maxspike_current, initburst_sahp.rheobase_current, initburst_sahp.steady_state_current, initburst_sahp_ssse.maxspike_current, initburst_sahp_ssse.rheobase_current, initburst_sahp_ssse.steady_state_current, initburst_sahp_vb.maxspike_current, initburst_sahp_vb.rheobase_current, initburst_sahp_vb.steady_state_current, interburst_voltage.maxspike_current, interburst_voltage.rheobase_current, interburst_voltage.steady_state_current, inv_fifth_ISI.rheobase_prev_current, inv_first_ISI.rheobase_prev_current, inv_fourth_ISI.rheobase_prev_current, inv_last_ISI.rheobase_prev_current, inv_second_ISI.rheobase_prev_current, inv_third_ISI.rheobase_prev_current, inv_time_to_first_spike.rheobase_prev_current, irregularity_index.rheobase_current, max_amp_difference.rheobase_current, min_voltage_between_spikes.rheobase_current, number_initial_spikes.rheobase_prev_current, single_burst_ratio.rheobase_current, spike_width2.rheobase_current, time_to_last_spike.rheobase_prev_current, time_to_second_spike.rheobase_current
# Number of features succesfully evaluated: 209/273
# Results are saved in the directory:  ./validation_results/results/somaticfeat/Hu_(WB)_2018_rb_standard/
