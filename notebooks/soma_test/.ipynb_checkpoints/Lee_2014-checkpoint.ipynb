# %%
from __future__ import print_function

# %matplotlib inline

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# 8.2.3

# %%
# This cell should have a 'parameters' tag for papermill parameterized notebook execution
results_folder = 'path_to_base_directory'     # MOUSE or RAT
target_data = 'path_to_target_data'           # MOUSE or RAT
stim_data = 'path_to_stim_file'               # MOUSE or RAT

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "/home/szabobogi/BC_modells/CA1_Lee_2014/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = results_folder

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Lee_2014"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/szabobogi/BC_modells/CA1_Lee_2014/class_pvbasketcell.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = "pvbasketcell()"

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = "soma_list"
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = None

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -65
#model.dt = 0.1

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - with global features
#
# It evaluates the model against experimental eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection using standardized current amplitudes.

# %%
# Load target data 
with open(target_data) as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
with open(stim_data, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTestWithGlobalFeatures(
    observation=observation, 
    config=config, 
    force_run=True, 
    show_plot=False, 
    save_all = True, 
    base_directory=base_directory,
    AP_detection_thd = -10,
    steady_state_threshold=30,
    highfreq_firing_threshold=150)


# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -0.1 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: -0.08 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: -0.07 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: -0.09 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: -0.05 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)- running amplitude: -0.04 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)- running amplitude: -0.03 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
#
#
# - running amplitude: -0.06 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: -0.02 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)- running amplitude: -0.01 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
#
# - running amplitude: 0.01 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.02 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.03 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.04 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.05 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.06 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.07 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.08 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.09 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.1 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.15 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.2 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.25 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.3 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.4 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.5 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# - running amplitude: 0.6 on model: Lee_2014_standard at: pvbasketcell[0].soma(0.5)
# INFO:root:Edge case detected in slope feature calculation: rheobase current = 0.4, steady state current = 0.4, maxspike current = 0.6
# The figures are saved in the directory:  ./validation_results/figs/somaticfeat/Lee_2014_standard/
# /usr/local/lib/python3.8/dist-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# /home/szabobogi/hippounit_standard_features/hippounit/hippounit/scores/score_ZScore_somaticSpiking.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   feature_error = abs(p_value - o_mean)/o_std
# Features excluded (due to invalid values): Spikecount.rheobase_prev_current, Spikecount_stimint.rheobase_prev_current, initburst_sahp.maxspike_current, initburst_sahp_ssse.maxspike_current, initburst_sahp_vb.maxspike_current, interburst_voltage.maxspike_current, interburst_voltage.rheobase_current, interburst_voltage.steady_state_current, inv_fifth_ISI.rheobase_prev_current, inv_first_ISI.rheobase_prev_current, inv_fourth_ISI.rheobase_prev_current, inv_last_ISI.rheobase_prev_current, inv_second_ISI.rheobase_prev_current, inv_third_ISI.rheobase_prev_current, inv_time_to_first_spike.rheobase_prev_current, number_initial_spikes.rheobase_prev_current, time_to_last_spike.rheobase_prev_current
# Number of features succesfully evaluated: 256/273
# Results are saved in the directory:  ./validation_results/results/somaticfeat/Lee_2014_standard/
