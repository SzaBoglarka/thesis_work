# %%
from __future__ import print_function

# %matplotlib inline

import sys
import os
#sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# 8.2.3

# %%
# Parameters
results_folder = "/home/szabobogi/hippounit_standard_features/validation_results_TEST/"
target_data = "/home/szabobogi/BluePyEfe_standard_features/BluePyEfe/FINAL_PV_PTI_data/features_for_validation/standard_features_for_validation_RAT_FINAL.json"
stim_data = "/home/szabobogi/BluePyEfe_standard_features/BluePyEfe/FINAL_PV_PTI_data/stim_for_validation/stim_for_validation_RAT_FINAL.json"

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "/home/szabobogi/BC_modells/CA1_Stacey_2009/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = results_folder

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="TEST(Stacey_vd)"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/szabobogi/BC_modells/CA1_Stacey_2009/Bwb_vd.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = "Bwb()"

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = "Bwb[0].soma"

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -65
#model.dt = 0.1

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - with global features
#
# It evaluates the model against experimental eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection using standardized current amplitudes.

# %%
# Load target data 
with open(target_data) as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
with open(stim_data, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTestWithGlobalFeatures(
    observation=observation, 
    config=config, 
    force_run=True, 
    show_plot=False, 
    save_all = True, 
    base_directory=base_directory,
    AP_detection_thd=-10,
    steady_state_threshold=30,
    highfreq_firing_threshold=150,
    # AP_down_der_thd=-14
    )


# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# efel version: 5.5.2
# AP detection threshold is set to -10
# Down Derivative threshold is set to -14
# - running amplitude: -0.1 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: -0.02 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.02 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)- running amplitude: 0.06 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
#
# - running amplitude: 0.25 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)- running amplitude: 0.08 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)- running amplitude: 0.1 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
#
# - running amplitude: 0.04 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
#
# - running amplitude: 0.15 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)- running amplitude: 0.2 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
#
# - running amplitude: 0.3 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.35 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.4 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.5 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.6 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.7 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.8 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# - running amplitude: 0.9 on model: TEST(Stacey_vd) at: Bwb[0].soma(0.5)
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature burst_mean_freq: The feature is found in the feature dictionary but it is empty. Feature burst_ISI_indices is empty
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature burst_mean_freq: The feature is found in the feature dictionary but it is empty. Feature burst_ISI_indices is empty
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature interburst_voltage: The feature is found in the feature dictionary but it is empty. Feature burst_ISI_indices is empty
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature interburst_voltage: The feature is found in the feature dictionary but it is empty. Feature burst_ISI_indices is empty
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature min_AHP_values:
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature min_AHP_values:
#   warnings.warn(
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/efel/api.py:445: RuntimeWarning: Error while calculating feature min_AHP_values:
#   warnings.warn(
# The figures are saved in the directory:  /home/szabobogi/hippounit_standard_features/validation_results_TEST/figs/somaticfeat/TEST(Stacey_vd)/
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1103: RuntimeWarning: All-NaN axis encountered
#   minx = np.nanmin(masked_verts[..., 0])
# /home/szabobogi/hippounit_standard_features/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1104: RuntimeWarning: All-NaN axis encountered
#   maxx = np.nanmax(masked_verts[..., 0])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /home/szabobogi/hippounit_standard_features/hippounit/scores/score_ZScore_somaticSpiking.py:38: RuntimeWarning: invalid value encountered in scalar divide
#   feature_error = abs(p_value - o_mean)/o_std
# Features excluded (due to invalid values): burst_mean_freq.rheobase_current, burst_mean_freq.steady_state_current, burst_number.highfreq_firing_current, interburst_voltage.rheobase_current, interburst_voltage.steady_state_current, min_AHP_values.highfreq_firing_current, min_AHP_values.rheobase_current, min_AHP_values.steady_state_current
# Number of features succesfully evaluated: 244/252
# Results are saved in the directory:  /home/szabobogi/hippounit_standard_features/validation_results_TEST/results/somaticfeat/TEST(Stacey_vd)/
# /home/szabobogi/hippounit_standard_features/hippounit/plottools.py:119: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figname, facecolor='white')
# /home/szabobogi/hippounit_standard_features/hippounit/tests/test_SomaticFeaturesTest.py:1028: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize = (210/25.4, 297/25.4))
